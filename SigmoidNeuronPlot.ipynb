# %% [markdown]
# <a href="https://colab.research.google.com/github/gourabdg47/padahiMLpractice/blob/main/SigmoidNeuronPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoind(x, w, b):
  return 1/(1 + np.exp(-(w*x + b)))

# %%
sigmoind(1, 0.5, 0)
# Out:
# 0.6224593312018546

# %%
w = -1.8   #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = -1.5 #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10, 10, 100)
Y = sigmoind(X, w, b)

plt.plot(X, Y)
plt.show()

# %% [markdown]
# $S_{w_1, w_2, b}(x_1,x_2)=\frac{1}{1 + e^{-(w_1x_1  + w_2x_2 + b)}}$

# %%
def  sigmoid_2d(x1, x2, w1, w2, b):
  return 1/(1 + np.exp(-(w1*x1 + w2*x2 + b)))

# %%
sigmoid_2d(1, 0, 0.5, 0, 0)
# Out:
# 0.6224593312018546

# %%
from mpl_toolkits import mplot3d

# %%
X1 = np.linspace(-10, 10, 100)
X2 = np.linspace(-10, 10, 100)

XX1, XX2 = np.meshgrid(X1, X2)
print(X1.shape, X2.shape, XX1.shape, XX2.shape)
# Out:
# (100,) (100,) (100, 100) (100, 100)

# %%
w1 = 0.5
w2 = 2
b = 0

Y = sigmoid_2d(XX1, XX2, w1, w2, b)

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection = '3d')
ax.plot_surface(XX1, XX2, Y, cmap = 'viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
ax.view_init(30, 180)
fig
